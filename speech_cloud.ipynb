# %%
from konlpy.tag import Kkma
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict
from collections import Counter
import webbrowser
kkma=Kkma()
f=open("speech.txt",mode='r',encoding='utf-8')
txt=f.read()
f.close()
speech=kkma.sentences(txt)

# %%
#TFIDF
tfidf = TfidfVectorizer() 
txt_matrix= tfidf.fit_transform(speech) #연설로 특성 행렬을 만든다.
word_id=defaultdict(lambda : 0) 
for idx,feature in enumerate(tfidf.get_feature_names()): #단어 목록에 index(순서) 부여
    word_id[feature] = idx
print('----------------------------------------------------------')
print("연설문에 대한 TF-IDF 출력")
print('----------------------------------------------------------')
speech_word=[]
for i, s in enumerate(speech):
    for token in s.split():
        if txt_matrix[i,word_id[token]]>0:# idf 값이 0인것은 제외한다.
            speech_word.append(token)
            print(((token,txt_matrix[i,word_id[token]]))) # 단어에 해당하는 idf 값을 출력하기 위함
# Out:
# ----------------------------------------------------------
# 연설문에 대한 TF-IDF 출력
# ----------------------------------------------------------
# ('경제', 0.3508345017262598)
# ('활성화에', 0.3934837249053176)
# ('대한', 0.3934837249053176)
# ('국민의', 0.32057439631335005)
# ('기대가', 0.3934837249053176)
# ('대단히', 0.3934837249053176)
# ('정부', 0.30421486320417984)
# ('출범과', 0.3411967664415787)
# ('함께', 0.3411967664415787)
# ('이곳', 0.3411967664415787)
# ('천에', 0.3411967664415787)
# ('제일', 0.3411967664415787)
# ('먼저', 0.30421486320417984)
# ('오게', 0.3411967664415787)
# ('취임사에서', 0.36798265402999464)
# ('밝힌', 0.36798265402999464)
# ('있지만', 0.36798265402999464)
# ('앞으로', 0.3280974609600051)
# ('5년', 0.3280974609600051)
# ('매우', 0.3280974609600051)
# ('중요한', 0.36798265402999464)
# ('세계는', 0.3581729306559009)
# ('바야흐로', 0.3581729306559009)
# ('냉혹한', 0.3581729306559009)
# ('기술전쟁의', 0.3581729306559009)
# ('시대를', 0.3581729306559009)
# ('맞고', 0.3581729306559009)
# ('우리나라가', 0.5773502691896257)
# ('선진국으로', 0.5773502691896257)
# ('후진국으로', 0.7071067811865475)
# ('전락하느냐', 0.7071067811865475)
# ('하는', 0.41617114486261303)
# ('것이', 0.41617114486261303)
# ('내에', 0.46676302208846976)
# ('판가름', 0.46676302208846976)
# ('아울러', 0.4790493519298399)
# ('통일에', 0.4790493519298399)
# ('대해서도', 0.4790493519298399)
# ('대비해야', 0.4790493519298399)
# ('나는', 0.43172957733882156)
# ('국민들에게', 0.38493493265217205)
# ('건설을', 0.43172957733882156)
# ('국민의', 0.2930265598601816)
# ('참여와', 0.35967059002825813)
# ('창의를', 0.35967059002825813)
# ('끌어', 0.35967059002825813)
# ('경제발전의', 0.35967059002825813)
# ('새로운', 0.35967059002825813)
# ('바탕을', 0.35967059002825813)
# ('만들자는', 0.32068633148300396)
# ('신경제', 0.2421523777850193)
# ('건설하기', 0.32070720424534377)
# ('위해서는', 0.32070720424534377)
# ('시대에', 0.32070720424534377)
# ('맞지', 0.32070720424534377)
# ('않는', 0.32070720424534377)
# ('규제와', 0.32070720424534377)
# ('간섭을', 0.32070720424534377)
# ('과감히', 0.28594613977620315)
# ('없애야', 0.32070720424534377)
# ('국민', 0.2947174523556711)
# ('각자가', 0.3305448021129869)
# ('흘린', 0.3305448021129869)
# ('만큼', 0.3305448021129869)
# ('정당한', 0.3305448021129869)
# ('보상을', 0.3305448021129869)
# ('받도록', 0.3305448021129869)
# ('되어', 0.27110246376530317)
# ('신경제', 0.22958206841164194)
# ('5개년', 0.3040590556188045)
# ('만들자는', 0.27110246376530317)
# ('임기', 0.40600654887927656)
# ('5년', 0.3619999920147507)
# ('동안의', 0.40600654887927656)
# ('경제개혁', 0.40600654887927656)
# ('경제운영계획을', 0.40600654887927656)
# ('말하는', 0.40600654887927656)
# ('기초연구는', 0.5277841425128352)
# ('이미', 0.5277841425128352)
# ('되어', 0.47057826013532666)
# ('금년', 0.41319137960337415)
# ('6월까지', 0.46342102143636854)
# ('완성하여', 0.41319137960337415)
# ('하반기부터', 0.46342102143636854)
# ('실시하도록', 0.41319137960337415)
# ('금년', 0.3573170704683064)
# ('상반기에', 0.40075434761495504)
# ('대하여는', 0.40075434761495504)
# ('‘', 0.40075434761495504)
# ('신경제', 0.3025925732195474)
# ('100일', 0.40075434761495504)
# ('계획’', 0.40075434761495504)
# ('을', 0.40075434761495504)
# ('수립할', 0.3573170704683064)
# ('것입니다.', 0.40075434761495504)
# ('3월', 0.6485895269643126)
# ('20일까지', 0.39805022787134486)
# ('완성하여', 0.35490604698039496)
# ('3월', 0.6485895269643126)
# ('21일부터', 0.35490604698039496)
# ('실시하도록', 0.35490604698039496)
# ('부총리를', 0.20082519694420556)
# ('비롯한', 0.20082519694420556)
# ('경제장관', 0.20082519694420556)
# ('여러분들은', 0.20082519694420556)
# ('합심', 0.20082519694420556)
# ('단결하여', 0.20082519694420556)
# ('빠른', 0.20082519694420556)
# ('시일', 0.20082519694420556)
# ('안에', 0.20082519694420556)
# ('우리가', 0.20082519694420556)
# ('당면하고', 0.20082519694420556)
# ('있는', 0.20082519694420556)
# ('경제의', 0.20082519694420556)
# ('어려움을', 0.20082519694420556)
# ('우리', 0.20082519694420556)
# ('경제가', 0.20082519694420556)
# ('앞으로', 0.17905799768707586)
# ('전진해', 0.20082519694420556)
# ('나갈', 0.20082519694420556)
# ('있도록', 0.20082519694420556)
# ('배전의', 0.20082519694420556)
# ('노력을', 0.20082519694420556)
# ('주기', 0.20082519694420556)

# %%
import pytagcloud
speech_cnt={}
for word in speech_word:
    speech_cnt[word]=speech_cnt.get(word,0)+1
print(speech_cnt)
# Out:
# {'경제': 2, '활성화에': 1, '대한': 1, '국민의': 3, '기대가': 1, '대단히': 1, '정부': 2, '출범과': 1, '함께': 1, '이곳': 1, '천에': 1, '제일': 1, '먼저': 2, '오게': 1, '취임사에서': 1, '밝힌': 1, '있지만': 1, '앞으로': 2, '5년': 2, '매우': 2, '중요한': 1, '세계는': 1, '바야흐로': 1, '냉혹한': 1, '기술전쟁의': 1, '시대를': 1, '맞고': 1, '우리나라가': 1, '선진국으로': 1, '후진국으로': 1, '전락하느냐': 1, '하는': 2, '것이': 2, '내에': 1, '판가름': 1, '아울러': 1, '통일에': 1, '대해서도': 1, '대비해야': 1, '나는': 1, '국민들에게': 2, '건설을': 1, '참여와': 1, '창의를': 1, '끌어': 1, '경제발전의': 1, '새로운': 1, '바탕을': 1, '만들자는': 2, '신경제': 3, '건설하기': 1, '위해서는': 1, '시대에': 1, '맞지': 1, '않는': 1, '규제와': 1, '간섭을': 1, '과감히': 2, '없애야': 1, '국민': 2, '각자가': 1, '흘린': 1, '만큼': 1, '정당한': 1, '보상을': 1, '받도록': 1, '경제정의를': 1, '확립해야': 1, '이를': 2, '위해서': 1, '금융제도를': 1, '개혁해야': 1, '우선': 1, '시급한': 1, '것은': 2, '경제행정': 1, '규제를': 3, '완화하는': 1, '3월': 4, '20일을': 1, '기해서': 1, '규제': 2, '실태를': 1, '조사해서': 2, '규제완화': 1, '방안을': 1, '수립할': 2, '실태는': 1, '뿐만': 1, '받는': 1, '기업': 1, '측에서도': 1, '제출하도록': 1, '그리고': 2, '법이나': 1, '규정에': 1, '의한': 2, '규제뿐만': 1, '아니라': 1, '관행에': 1, '없애는': 1, '데에도': 1, '철저를': 1, '기할': 1, '21일부터': 2, '즉시': 1, '규정의': 1, '개정작업에': 1, '착수토록': 1, '이와': 1, '같은': 1, '개혁과': 1, '더불어': 1, '각자의': 1, '의식도': 1, '새로워져야': 1, '모든': 1, '국민이': 1, '동반자의식': 1, '고통을': 1, '분담해야': 1, '요구하기에': 1, '공직자들이': 1, '솔선수범해야': 1, '정부의': 1, '정책은': 1, '신뢰를': 1, '얻는': 1, '따라서': 1, '앞으로의': 1, '경제정책은': 1, '자률': 1, '원칙에': 1, '따라': 1, '추진되어야': 1, '오늘': 1, '특별히': 1, '지시하고자': 1, '부총리가': 1, '중심이': 1, '되어': 2, '5개년': 1, '임기': 1, '동안의': 1, '경제개혁': 1, '경제운영계획을': 1, '말하는': 1, '기초연구는': 1, '이미': 1, '금년': 2, '6월까지': 1, '완성하여': 2, '하반기부터': 1, '실시하도록': 2, '상반기에': 1, '대하여는': 1, '‘': 1, '100일': 1, '계획’': 1, '을': 1, '것입니다.': 1, '20일까지': 1, '부총리를': 1, '비롯한': 1, '경제장관': 1, '여러분들은': 1, '합심': 1, '단결하여': 1, '빠른': 1, '시일': 1, '안에': 1, '우리가': 1, '당면하고': 1, '있는': 1, '경제의': 1, '어려움을': 1, '우리': 1, '경제가': 1, '전진해': 1, '나갈': 1, '있도록': 1, '배전의': 1, '노력을': 1, '주기': 1}

# %%
for key,value in list(speech_cnt.items()):
    if key=='것이' or key=='것은' or key=='하는' or key=='이를': # 2번 이상 등장하는 쓸모없는 어절 제거
        del speech_cnt[key]
cnt=Counter(speech_cnt)

n=cnt.most_common(50) # 상위 50개의 단어
print(n)
speech_wc=pytagcloud.make_tags(n,maxsize=80) # 워드 클라우드 생성
pytagcloud.create_tag_image(speech_wc,'speech.png',size=(1000,600),
                            fontname='korean',rectangular=False
                            )
webbrowser.open('speech.png') #모니터에 사진을 띄운다.
# Out:
# [('3월', 4), ('국민의', 3), ('신경제', 3), ('규제를', 3), ('경제', 2), ('정부', 2), ('먼저', 2), ('앞으로', 2), ('5년', 2), ('매우', 2), ('국민들에게', 2), ('만들자는', 2), ('과감히', 2), ('국민', 2), ('규제', 2), ('조사해서', 2), ('수립할', 2), ('그리고', 2), ('의한', 2), ('21일부터', 2), ('되어', 2), ('금년', 2), ('완성하여', 2), ('실시하도록', 2), ('활성화에', 1), ('대한', 1), ('기대가', 1), ('대단히', 1), ('출범과', 1), ('함께', 1), ('이곳', 1), ('천에', 1), ('제일', 1), ('오게', 1), ('취임사에서', 1), ('밝힌', 1), ('있지만', 1), ('중요한', 1), ('세계는', 1), ('바야흐로', 1), ('냉혹한', 1), ('기술전쟁의', 1), ('시대를', 1), ('맞고', 1), ('우리나라가', 1), ('선진국으로', 1), ('후진국으로', 1), ('전락하느냐', 1), ('내에', 1), ('판가름', 1)]
